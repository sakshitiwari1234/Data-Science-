# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshitiwari1234/Data-Science-/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# overview
# understanding  data -  datatypes.
#                     data summary.

# %%
import pandas as pd
df=  pd.DataFrame({'weight':[65,45,67,71,54],
                   'name':['sakshi', 'aditya', 'muskan', 'parul', 'anurag'],
                   'gender':['female', 'male', 'female', 'female', 'male'],
                   'age':[23,34,32,23,23],
                   'isgraduated':[False, True, True, False, True]})

# %%
df
# Out:
#    weight    name  gender  age  isgraduated
# 0      65  sakshi  female   23        False
# 1      45  aditya    male   34         True
# 2      67  muskan  female   32         True
# 3      71   parul  female   23        False
# 4      54  anurag    male   23         True

# %%
df.dtypes
# Out:
# weight          int64
# name           object
# gender         object
# age             int64
# isgraduated      bool
# dtype: object

# %%
df.describe()
# Out:
#           weight        age
# count   5.000000   5.000000
# mean   60.400000  27.000000
# std    10.667708   5.522681
# min    45.000000  23.000000
# 25%    54.000000  23.000000
# 50%    65.000000  23.000000
# 75%    67.000000  32.000000
# max    71.000000  34.000000

# %%
df.describe(include = 'all')
# Out:
#            weight    name  gender        age isgraduated
# count    5.000000       5       5   5.000000           5
# unique        NaN       5       2        NaN           2
# top           NaN  sakshi  female        NaN        True
# freq          NaN       1       3        NaN           3
# mean    60.400000     NaN     NaN  27.000000         NaN
# std     10.667708     NaN     NaN   5.522681         NaN
# min     45.000000     NaN     NaN  23.000000         NaN
# 25%     54.000000     NaN     NaN  23.000000         NaN
# 50%     65.000000     NaN     NaN  23.000000         NaN
# 75%     67.000000     NaN     NaN  32.000000         NaN
# max     71.000000     NaN     NaN  34.000000         NaN

# %% [markdown]
# What is Data Preprocessing

# %% [markdown]
# question -  why is data preprocesing important ?

# %% [markdown]
# quetion- what are the key steps in data preprocessing technique?
#
# keysteps are -
#
# Data Integration.
# Data Cleaning.
# Data Transformation.
# Data REduction and Dimension Reduction.

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# handle incorrectness, incompelte , inconsistent and handling misssing values.

# %% [markdown]
# data cleaning techniques include -
# Handling mising values.  - removing and imputing.
#
# DE-noising - denoising is  a tchnique to remove the noise from the data. noisy data is meaningless data, that is not interpretable and understandable by human beings. it can occur due to data entry error faulty data collection etc.
#
# --biinning the feature using regression to smoothen the feature tor reduce noise , clutering to detect the outleirs etc.

# %% [markdown]
# ### Data Integration.

# %% [markdown]
# a few of  the issues to be considered for data integration are as follows -
#
# entity identification problem.
# schema integration.
# --detecting and resolving data value concepts.

# %% [markdown]
# ### Data Reduction.

# %% [markdown]
# means to reduce the size of the input data. its main objective is to reduce the storage space capacity and then analysing the cost and improve storage efficiency.
#
# a few popular technique to perfrom data reduction include -
#
# -- Dimensionality Reduction.
#
# -- numerosity reduction.-- choosing alternative other method to perfrom same thing in one line of code.
#
# -- Data Compression. -> data is compresed , it can be lossless or lossy depending upon whether the information is lost or not after compresion.
#
#
# --

# %% [markdown]
# ### data Transformation.

# %% [markdown]
# few common method for data transformation include-
#
# 1. Smoothing.
# 2. Aggregation.
# 3. Discretization.   -  converting data into bins and intervals to understand easily.
# 4. Nomralization - converting numeric variable into specfied range such as [-1,1][0,1].
#
# common appoach to perform normalization technique are - Min-Max normalization.
#              - DAta standardization or data scaling etc.

# %% [markdown]
# ### Applicationss of Data Preprocessing.

# %% [markdown]
# DP is importat to do beofre we built any basic model of machine learning and AI application devlopment lifecycle.
#
# 1. improved acuraccy of machine learning models.
# 2. reduced costs.
# 3. Visualizations.
